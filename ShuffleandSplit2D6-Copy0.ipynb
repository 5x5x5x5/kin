# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Load dataframe and count number of cases positive and negative cases

# %%
isozyme2d6 = pd.read_csv('data/2d6.csv')

# %%
# Renaming the Activity Score column to conform to Python syntax
isozyme2d6.rename(columns={'p450-cyp2d6-ActivityScore': 'ActivityScore'}, inplace=True)

# %%
# Number of substances with an activity scores greater than or equal to 40
n_pos = (isozyme2d6.ActivityScore >= 40).sum()
n_pos
# Out:
# 2771

# %%
# Number of substances with an activity score below 40
n_neg = (isozyme2d6.ActivityScore < 40).sum()
n_neg
# Out:
# 14372

# %% [markdown]
# ##Downsampling the negative cases
#     This section of code shuffles the order of substances with an Activity Score below 40 (negatives). Then counts the number of substances with an Activity Score 40 or above (positives) and uses that number as a cutoff value on the list of negatives. When complete, there are an equal number of positives and negatives.
#     The seed value is set for the randomizer to ensure reproducibility. Different seeds will result in different negatives being included in the analysis set. All of the positives are always included in the resulting dataset.

# %%
# method adapted from DataRobot post about scikit-learn classification

# Downsample negative cases -- there are many more negatives than positives

indices = np.where(isozyme2d6.ActivityScore < 40)[0]
rng = np.random.RandomState(50)  # sets seed for random number generator
rng.shuffle(indices)             # different seed numbers result in different shuffle
n_pos = (isozyme2d6.ActivityScore >= 40).sum()
balanced = isozyme2d6.drop(isozyme2d6.index[indices[n_pos:]])

balanced.head(10)
# Out:
#        SID  ActivityScore       apol  a_acc  a_acid  a_aro  a_base  a_count  \
# 5   842618             44  70.986168      5       0     17       2       64
# 9   842953             44  62.660240      3       0     12       1       52
# 14  843293              0  60.107033      3       0      0       0       51
# 18  843526             41  45.001102      3       0     11       0       36
# 21  843662             40  65.452202      3       0     15       1       57
# 29  844085             41  43.942272      2       0      0       0       37
# 31  844156              0  62.506241      3       0     13       0       53
# 42  844873             41  66.039825      6       0     11       0       57
# 44  844963             66  47.919479      3       0     17       0       40
# 48  845384             42  66.798203      4       0     12       1       58
#
#     a_don  a_heavy  a_hyd        a_IC     a_ICM  a_nB  a_nBr  a_nC  a_nCl  \
# 5       0       31     22   93.841583  1.466275     0      0    23      0
# 9       1       29     21   88.142273  1.695044     0      0    21      2
# 14      1       27     17   82.816032  1.623844     0      0    20      0
# 18      2       22     15   62.059444  1.723873     0      0    16      0
# 21      0       29     22   82.217224  1.442408     0      0    23      0
# 29      2       19     12   56.388157  1.524004     0      0    14      0
# 31      0       30     17   90.934662  1.715748     0      0    21      0
# 42      3       32     18  100.920380  1.770533     0      0    21      0
# 44      1       23     16   61.576717  1.539418     0      0    18      0
# 48      1       30     21   94.294579  1.625768     0      0    22      0
#
#     a_nF  a_nH  a_nI
# 5      0    33     0 ...
# 9      0    23     0 ...
# 14     0    24     0 ...
# 18     0    14     0 ...
# 21     0    28     0 ...
# 29     0    18     0 ...
# 31     0    23     0 ...
# 42     0    25     0 ...
# 44     0    17     0 ...
# 48     0    28     0 ...
#
# [10 rows x 188 columns]

# %%
# Demonstrate the dataset is balanced
n_pos = (balanced.ActivityScore >= 40).sum()
n_neg = (balanced.ActivityScore < 40).sum()
n_neg, n_pos
# Out:
# (2771, 2771)

# %%
# Repeat code with different seed number to demonstrate shuffling

indices2 = np.where(isozyme2d6.ActivityScore < 40)[0]
rng2 = np.random.RandomState(353655)  # sets seed for random number generator
rng2.shuffle(indices2)             # different seed numbers result in different shuffle
n_pos2 = (isozyme2d6.ActivityScore >= 40).sum()
balanced2 = isozyme2d6.drop(isozyme2d6.index[indices2[n_pos2:]])

balanced2.head(10)
# Out:
#        SID  ActivityScore       apol  a_acc  a_acid  a_aro  a_base  a_count  \
# 5   842618             44  70.986168      5       0     17       2       64
# 7   842789              0  59.769032      3       0     12       0       52
# 9   842953             44  62.660240      3       0     12       1       52
# 11  843048             20  57.944275      7       0     23       0       47
# 18  843526             41  45.001102      3       0     11       0       36
# 20  843632             22  68.429787      5       0     11       0       60
# 21  843662             40  65.452202      3       0     15       1       57
# 22  843808              0  49.809307      5       0     19       0       39
# 24  843859              0  45.908276      3       0      0       0       39
# 29  844085             41  43.942272      2       0      0       0       37
#
#     a_don  a_heavy  a_hyd       a_IC     a_ICM  a_nB  a_nBr  a_nC  a_nCl  \
# 5       0       31     22  93.841583  1.466275     0      0    23      0
# 7       3       28     18  81.390213  1.565196     0      0    21      0
# 9       1       29     21  88.142273  1.695044     0      0    21      2
# 11      4       29     15  81.296402  1.729711     0      0    19      0
# 18      2       22     15  62.059444  1.723873     0      0    16      0
# 20      1       30     19  96.344337  1.605739     0      0    22      0
# 21      0       29     22  82.217224  1.442408     0      0    23      0
# 22      2       26     17  72.966324  1.870931     0      0    18      0
# 24      1       21     13  65.713791  1.684969     0      0    15      0
# 29      2       19     12  56.388157  1.524004     0      0    14      0
#
#     a_nF  a_nH  a_nI
# 5      0    33     0 ...
# 7      0    24     0 ...
# 9      0    23     0 ...
# 11     0    18     0 ...
# 18     0    14     0 ...
# 20     0    30     0 ...
# 21     0    28     0 ...
# 22     1    13     0 ...
# 24     0    18     0 ...
# 29     0    18     0 ...
#
# [10 rows x 188 columns]

# %% [markdown]
# ## Write files for analysis

# %%
balanced.to_csv("data/balanced2d6.csv", index=False)

# %% [markdown]
# ## Generate Training and Test Set

# %%
twoD6 = pd.read_csv("data/balanced2d6.csv")

# %%
twoD6.head()
# Out:
#       SID  ActivityScore       apol  a_acc  a_acid  a_aro  a_base  a_count  \
# 0  842618             44  70.986168      5       0     17       2       64
# 1  842953             44  62.660240      3       0     12       1       52
# 2  843293              0  60.107033      3       0      0       0       51
# 3  843526             41  45.001102      3       0     11       0       36
# 4  843662             40  65.452202      3       0     15       1       57
#
#    a_don  a_heavy  a_hyd       a_IC     a_ICM  a_nB  a_nBr  a_nC  a_nCl  a_nF  \
# 0      0       31     22  93.841583  1.466275     0      0    23      0     0
# 1      1       29     21  88.142273  1.695044     0      0    21      2     0
# 2      1       27     17  82.816032  1.623844     0      0    20      0     0
# 3      2       22     15  62.059444  1.723873     0      0    16      0     0
# 4      0       29     22  82.217224  1.442408     0      0    23      0     0
#
#    a_nH  a_nI
# 0    33     0 ...
# 1    23     0 ...
# 2    24     0 ...
# 3    14     0 ...
# 4    28     0 ...
#
# [5 rows x 188 columns]

# %% [markdown]
# ### Shuffle and split dataset while preserving pandas index and metadata.

# %%
# Method adapted to Python3 from function by boates at https://gist.github.com/boates/5127281
N = len(twoD6)

# %%
l = list(range(N))

# %%
shuffle(l)

# %%
# get splitting indicies
# Here they are set to 80% training, 0% cross-validation and 20% test sets
trainLen = int(N*.8)
cvLen    = int(N*0.0)
testLen  = int(N*.2)

# %%
# get training, cv, and test sets
training = twoD6.ix[l[:trainLen]]
cv       = twoD6.ix[l[trainLen:trainLen+cvLen]]
test     = twoD6.ix[l[trainLen+cvLen:]]

# %%
# Examine training set
training.head()
# Out:
#            SID  ActivityScore       apol  a_acc  a_acid  a_aro  a_base  \
# 3635  14734982             41  65.018242      3       0     20       0
# 4605  17407770              0  42.154690      3       2      6       0
# 2705  11112282             41  61.437031      6       0     12       1
# 543    4238560             40  53.362274      3       0     22       0
# 63      858386             41  55.370445      2       0     12       1
#
#       a_count  a_don  a_heavy  a_hyd       a_IC     a_ICM  a_nB  a_nBr  a_nC  \
# 3635       53      2       30     21  83.886292  1.582760     0      0    23
# 4605       36      2       20     10  64.501808  1.791717     0      0    13
# 2705       54      0       30     20  82.965843  1.536404     0      0    22
# 543        43      1       25     19  58.032070  1.349583     0      0    21
# 63         47      0       25     20  78.247559  1.664842     0      0    19
#
#       a_nCl  a_nF  a_nH  a_nI
# 3635      0     0    23     0 ...
# 4605      0     0    16     0 ...
# 2705      0     0    24     0 ...
# 543       0     0    18     0 ...
# 63        0     1    22     0 ...
#
# [5 rows x 188 columns]

# %%
test.shape
# Out:
# (1109, 188)

# %% [markdown]
# ## Write resulting training and test set to files for use in all further analyses.

# %%
training.to_csv("data/traing2d6.csv", index=False)
test.to_csv("data/test2d6.csv", index=False)
